# %%
import sys
import os
import psycopg2
import pandas as pd

# %%
from bokeh.plotting import figure, output_notebook, show, ColumnDataSource
from bokeh.charts import Scatter, output_file, show
from bokeh.models import HoverTool
import matplotlib as mpl
import matplotlib.cm as cmx

# %%
output_notebook()

TOOLS = "pan,wheel_zoom,box_zoom,undo,redo,reset,tap,save,box_select,poly_select,lasso_select"
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="4d8253ee-d444-445c-87cc-676a8857633a">Loading BokehJS ...</span>
#     </div>

# %%
conn = psycopg2.connect("host='localhost' dbname='ind'")
cursor = conn.cursor()

# %%
cursor.execute('select E.X1, E.X2, C.* from embedded E inner join company_dets C on E.id = C.id')
SNE_vecs = cursor.fetchall()
colnames = [desc[0] for desc in cursor.description]

# %%
vecs = pd.DataFrame(SNE_vecs, columns=colnames)
vecs.head()
# Out:
#          x1       x2                           id sec_header  \
# 0  0.096793 -4.24718    38725_10-K_2015-03-04.txt       None
# 1 -0.840741  3.99862  1444598_10-K_2015-03-16.txt       None
# 2  9.429000  5.55670   860413_10-K_2015-03-02.txt       None
# 3  9.048320 -6.08241  1453001_10-K_2015-04-15.txt       None
# 4 -4.322770  7.35713  1022469_10-K_2015-03-03.txt       None
#
#                         former_conformed_name film_number sec_file_number  \
# 0                                        None    15672604       000-00362
# 1                                        None    15703610       001-34435
# 2  FIRST INTERSTATE BANCSYSTEM OF MONTANA INC    15661208       001-34653
# 3                                        None    15772607       000-54997
# 4                                        None    15668624       001-12147
#
#   central_index_key sic_cd public_document_count  \
# 0        0000038725   3621                    19
# 1        0001444598   7389                    19
# 2        0000860413   6022                    13
# 3        0001453001   2834                    15
# 4        0001022469   2421                    13
#
#                          ...                                    street_2  \
# 0                        ...                                        None
# 1                        ...                                  SUITE 1000
# 2                        ...                          401 NO 31ST STREET
# 3                        ...                                        None
# 4                        ...                                200 EAST ELM
#
#     sec_act date_of_name_change conformed_submission_type  \
# 0  1934 Act                None                      10-K
# 1  1934 Act                None                      10-K
# 2  1934 Act            19930615                      10-K
# 3  1934 Act                None                      10-K
# 4  1934 Act                None                      10-K
#
#             company_conformed_name state_of_incorporation form_type  \
# 0         FRANKLIN ELECTRIC CO INC                     IN      10-K
# 1                      Emdeon Inc.                     DE      10-K
# 2  FIRST INTERSTATE BANCSYSTEM INC                     MT      10-K
# 3                   VACCINOGEN INC                     MD      10-K
# 4               DELTIC TIMBER CORP                     DE      10-K
#
#                               name  \
# 0         FRANKLIN ELECTRIC CO INC
# 1                       EMDEON INC
# 2  FIRST INTERSTATE BANCSYSTEM INC
# 3                   VACCINOGEN INC
# 4               DELTIC TIMBER CORP
#
#                                 business_description  \
# 0  item 0 . business general franklin electric co...
# 1  item 0 . business overview we are a leading pr...
# 2  item 0 . business the disclosures set forth in...
# 3  item 0 . description of business overview vacc...
# 4  item 0 . business introduction deltic timber c...
#
#                                      raw_description
# 0   ITEM 1. BUSINESS   General Franklin Electric ...
# 1   ITEM 1. BUSINESS   \n Overview  We are a lead...
# 2   Item 1. Business The disclosures set forth in...
# 3   Item 1. DESCRIPTION OF BUSINESS \n\n \n\n   \...
# 4   Item 1. Business    Introduction  \n Deltic T...
#
# [5 rows x 32 columns]

# %%
theme = cmx.get_cmap('viridis') 
cNorm = mpl.colors.Normalize(vmin=0, vmax=9999)
scalarMap = cmx.ScalarMappable(norm=cNorm, cmap=theme)
print scalarMap.get_clim()
# Out:
# (0, 9999)

# %%
colors = []
for s in vecs['sic_cd']:
    try:
        colorVal = scalarMap.to_rgba(int(s))
        colors.append("#%02x%02x%02x" % (colorVal[0]*255,colorVal[1]*255,colorVal[2]*255))
    except:
        colors.append("#d3d3d3")

# %%
source = ColumnDataSource(
        data=dict(
            x=list(vecs['x1']),
            y=list(vecs['x2']),
            desc=list(vecs['sic_cd']),
            name=list([v.title() for v in vecs['name']]),
        )
    )

hover = HoverTool(
        tooltips=[
            ("Name", "@name"),
            ("SIC", "@desc"),
        ]
    )

# %%
plot = figure(plot_width=800, tools=[hover, TOOLS])

# %%
plot.scatter('x', 'y', source=source, color=colors, alpha=.5, size=3)
plot.toolbar.logo = None
plot.axis.visible = False
plot.grid.visible = False

# %%
show(plot)
# Out:
#     <div class="bk-root">
#         <div class="plotdiv" id="a340553f-2cd9-480d-be4c-b38936efc34f"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = "";
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force !== "") {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force !== "") {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         Bokeh.$("#a340553f-2cd9-480d-be4c-b38936efc34f").text("BokehJS successfully loaded.");
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("a340553f-2cd9-480d-be4c-b38936efc34f");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'a340553f-2cd9-480d-be4c-b38936efc34f' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"efaaea1a-d3d6-4b1c-bebf-5fefaf260854":{"roots":{"references":[{"attributes":{"overlay":{"id":"3b8b7a9a-04a7-49e1-a56c-395188ad339b","type":"PolyAnnotation"},"plot":{"id":"8774dfed-0850-4fbd-8e84-bea5e0f6eda4","subtype":"Figure","type":"Plot"}},"id":"558470bb-8083-48a7-87a5-2f5a34c5eac2","type":"PolySelectTool"},{"attributes":{"data_source":{"id":"0c2f76db-f45d-4b44-b439-ce2e09e7b1e8","type":"ColumnDataSource"},"glyph":{"id":"e8ec00a0-a103-4e63-b104-630660d0b29b","type":"Circle"},"hover_glyph":null,"nonselection_glyph":{"id":"f9e9c7da-f27c-480a-b4b8-680df725622a","type":"Circle"},"selection_glyph":null},"id":"67ab37ca-b5aa-4928-a08a-e84da0ab92a1","type":"GlyphRenderer"},{"attributes":{"plot":{"id":"8774dfed-0850-4fbd-8e84-bea5e0f6eda4","subtype":"Figure","type":"Plot"}},"id":"1c43840f-0bb1-40d9-a941-10a292ebc70b","type":"SaveTool"},{"attributes":{"callback":null,"overlay":{"id":"bd412216-f7a0-482b-bbf3-7ba7ffd64389","type":"BoxAnnotation"},"plot":{"id":"8774dfed-0850-4fbd-8e84-bea5e0f6eda4","subtype":"Figure","type":"Plot"},"renderers":[{"id":"67ab37ca-b5aa-4928-a08a-e84da0ab92a1","type":"GlyphRenderer"}]},"id":"f1ffa050-b24a-4fe4-8b04-d60b175c246f","type":"BoxSelectTool"},{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"size":{"units":"screen","value":3},"x":{"field":"x"},"y":{"field":"y"}},"id":"f9e9c7da-f27c-480a-b4b8-680df725622a","type":"Circle"},{"attributes":{"below":[{"id":"f061a1b3-a150-44e6-9874-888e98231715","type":"LinearAxis"}],"left":[{"id":"d1f93fd7-ff9b-4f1b-9f43-806b47f78413","type":"LinearAxis"}],"plot_width":800,"renderers":[{"id":"f061a1b3-a150-44e6-9874-888e98231715","type":"LinearAxis"},{"id":"83ba6bd5-e557-4269-a57f-8b73b09cb9ab","type":"Grid"},{"id":"d1f93fd7-ff9b-4f1b-9f43-806b47f78413","type":"LinearAxis"},{"id":"7ded7893-47c6-4383-87a9-17c7d455a072","type":"Grid"},{"id":"2254f576-3aef-4f91-a37c-993a9cb4bc1c","type":"BoxAnnotation"},{"id":"bd412216-f7a0-482b-bbf3-7ba7ffd64389","type":"BoxAnnotation"},{"id":"3b8b7a9a-04a7-49e1-a56c-395188ad339b","type":"PolyAnnotation"},{"id":"91ce7ee2-ba3d-4f4f-874d-179848c188c6","type":"PolyAnnotation"},{"id":"67ab37ca-b5aa-4928-a08a-e84da0ab92a1","type":"GlyphRenderer"}],"title":{"id":"3da0c933-9a67-4c32-97ce-de68148d548d","type":"Title"},"tool_events":{"id":"a4232c2b-d07b-437a-8d5a-7d7fcc3d89bb","type":"ToolEvents"},"toolbar":{"id":"4982997c-858b-4951-af68-b4b493e9315e","type":"Toolbar"},"x_range":{"id":"4f826b35-c385-4471-a31e-894c45ed3438","type":"DataRange1d"},"y_range":{"id":"fc6377b4-9e4d-4ef9-9709-bb1d4fefe8ae","type":"DataRange1d"}},"id":"8774dfed-0850-4fbd-8e84-bea5e0f6eda4","subtype":"Figure","type":"Plot"},{"attributes":{"fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"xs_units":"screen","ys_units":"screen"},"id":"91ce7ee2-ba3d-4f4f-874d-179848c188c6","type":"PolyAnnotation"},{"attributes":{"callback":null,"plot":{"id":"8774dfed-0850-4fbd-8e84-bea5e0f6eda4","subtype":"Figure","type":"Plot"},"tooltips":[["Name","@name"],["SIC","@desc"]]},"id":"72d237ac-7f53-49a9-91ca-f2c280c27775","type":"HoverTool"},{"attributes":{"callback":null},"id":"4f826b35-c385-4471-a31e-894c45ed3438","type":"DataRange1d"},{"attributes":{"formatter":{"id":"423c547e-7df9-4ae5-b3f6-544cee096dce","type":"BasicTickFormatter"},"plot":{"id":"8774dfed-0850-4fbd-8e84-bea5e0f6eda4","subtype":"Figure","type":"Plot"},"ticker":{"id":"15e11aa2-59ca-479f-961e-1e9e8651cb26","type":"BasicTicker"},"visible":false},"id":"f061a1b3-a150-44e6-9874-888e98231715","type":"LinearAxis"},{"attributes":{},"id":"79b47770-1f80-4160-a486-e951e6c4c806","type":"BasicTickFormatter"},{"attributes":{"callback":null,"plot":{"id":"8774dfed-0850-4fbd-8e84-bea5e0f6eda4","subtype":"Figure","type":"Plot"}},"id":"ff2c835a-dc99-406a-845f-ba201a617a2b","type":"TapTool"}, ...
